# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Task 1: View Data

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# ## Task 2:  Clean Data

# %%
df.drop(['Row ID','Order ID','Customer ID','Customer Name'],axis=1,inplace=True)

# %%
df[df.duplicated()]
# Out:
#       Order Date   Ship Date       Ship Mode      Segment        Country  \
# 3406  23/04/2015  27/04/2015  Standard Class  Home Office  United States
#
#           City State  Postal Code Region       Product ID   Category  \
# 3406  Columbus  Ohio      43229.0   East  FUR-CH-10002965  Furniture
#
#      Sub-Category                                       Product Name    Sales
# 3406       Chairs  Global Leather Highback Executive Chair with P...  281.372

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code     11
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
#Show all Null Values in the Postal Code Column

df[df['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df['Postal Code'].fillna(5401, inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Task 3: Report

# %%
#Validate columns types

df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### What was the Best City for Sales?

# %%
top_cities= df.groupby("City").sum().sort_values("Sales",ascending=False).head(15)
top_cities= top_cities[['Sales']].round(2)
top_cities.reset_index(inplace=True)
top_cities

fig=px.bar(top_cities,x='City',y='Sales',title="Top 15 Cities",color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="54265780-1fae-43db-b254-59eee63cec87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54265780-1fae-43db-b254-59eee63cec87")) {                    Plotly.newPlot(                        "54265780-1fae-43db-b254-59eee63cec87",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#0d0887","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["New York City","Los Angeles","Seattle","San Francisco","Philadelphia","Houston","Chicago","San Diego","Jacksonville","Detroit","Springfield","Columbus","Newark","Columbia","Jackson"],"xaxis":"x","y":[252462.55,173420.18,1161
# ...

# %% [markdown]
# ### What was the Best State for Sales?

# %%
top_states= df.groupby("State").sum().sort_values("Sales",ascending=False).head(15)
top_states= top_states[['Sales']].round(2)
top_states.reset_index(inplace=True)
top_states
fig=px.bar(top_states,x='State',y='Sales',title="Top 15 States",color_discrete_sequence=px.colors.sequential.Viridis)
fig.show()
# Out:
# <div>                            <div id="3c343d7c-da05-4727-b5b3-ecaaf9a6bf98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c343d7c-da05-4727-b5b3-ecaaf9a6bf98")) {                    Plotly.newPlot(                        "3c343d7c-da05-4727-b5b3-ecaaf9a6bf98",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#440154","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["California","New York","Texas","Washington","Pennsylvania","Florida","Illinois","Michigan","Ohio","Virginia","North Carolina","Indiana","Georgia","Kentucky","Arizona"],"xaxis":"x","y":[446306.46,306361.15,168572.53,135206.8
# ...

# %% [markdown]
# ### The most common Ship Mode

# %%
fig = px.pie(df, values=np.ones(9800), names='Ship Mode', title='Ship Mode',color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <div>                            <div id="bfe9212c-28b5-4f0d-bd9b-59884bc8fde0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfe9212c-28b5-4f0d-bd9b-59884bc8fde0")) {                    Plotly.newPlot(                        "bfe9212c-28b5-4f0d-bd9b-59884bc8fde0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Ship Mode=%{label}<br>value=%{value}<extra></extra>","labels":["Second Class","Second Class","Second Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Standard Class","Second Class","Second Class","Second Class","Second Class","Sta
# ...

# %% [markdown]
# ### The Most Orders and the Best Category

# %%
fig = px.pie(df, values=np.ones(9800), names='Category', title='Category',color_discrete_sequence=px.colors.sequential.Hot)
fig.show()
# Out:
# <div>                            <div id="30e0a894-c2c7-4771-909b-636d63dddc03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30e0a894-c2c7-4771-909b-636d63dddc03")) {                    Plotly.newPlot(                        "30e0a894-c2c7-4771-909b-636d63dddc03",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}<br>value=%{value}<extra></extra>","labels":["Furniture","Furniture","Office Supplies","Furniture","Office Supplies","Furniture","Office Supplies","Technology","Office Supplies","Office Supplies","Furniture","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplie
# ...

# %%
categoris= df.groupby("Category").sum().sort_values("Sales",ascending=False).head(15)
categoris= categoris[['Sales']].round(2)
categoris.reset_index(inplace=True)

fig = px.pie(categoris, values='Sales', names='Category', title='Categoris sales',color_discrete_sequence=px.colors.sequential.Jet)
fig.show()
# Out:
# <div>                            <div id="f1bcd5f3-c600-45f7-8b31-5b6819e93f6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1bcd5f3-c600-45f7-8b31-5b6819e93f6f")) {                    Plotly.newPlot(                        "f1bcd5f3-c600-45f7-8b31-5b6819e93f6f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}<br>Sales=%{value}<extra></extra>","labels":["Technology","Furniture","Office Supplies"],"legendgroup":"","name":"","showlegend":true,"values":[827455.87,728658.58,705422.33],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22
# ...

# %% [markdown]
# ### The Most Orders Segment and the Best Segment for Sales

# %%
fig = px.pie(df, values=np.ones(9800), names='Segment', title='Segment',color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="1ae9228a-ce63-45d3-b89d-e9a388fdb97a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ae9228a-ce63-45d3-b89d-e9a388fdb97a")) {                    Plotly.newPlot(                        "1ae9228a-ce63-45d3-b89d-e9a388fdb97a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segment=%{label}<br>value=%{value}<extra></extra>","labels":["Consumer","Consumer","Corporate","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Home Office","Home Office","Consumer","Consumer","Consumer","Consumer","Consumer","Corporate","Corporate","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer","Consumer"
# ...

# %%
Segments= df.groupby("Segment").sum().sort_values("Sales",ascending=False)
Segments= Segments[['Sales']].round(2)
Segments.reset_index(inplace=True)

fig=px.pie(Segments,names='Segment',values='Sales',title="Segments Sales",color_discrete_sequence=px.colors.sequential.Jet)
fig.show()
# Out:
# <div>                            <div id="265406a4-730d-4395-9c03-1948f6ec69ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("265406a4-730d-4395-9c03-1948f6ec69ec")) {                    Plotly.newPlot(                        "265406a4-730d-4395-9c03-1948f6ec69ec",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segment=%{label}<br>Sales=%{value}<extra></extra>","labels":["Consumer","Corporate","Home Office"],"legendgroup":"","name":"","showlegend":true,"values":[1148060.53,688494.07,424982.18],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222
# ...

# %% [markdown]
# ### The Best Sub Category for Sales

# %%
fig = px.pie(df, values=np.ones(9800), names='Sub-Category', title='Sub Category',color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <div>                            <div id="517defe0-66a6-4e9b-88bb-6d2575758584" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("517defe0-66a6-4e9b-88bb-6d2575758584")) {                    Plotly.newPlot(                        "517defe0-66a6-4e9b-88bb-6d2575758584",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sub-Category=%{label}<br>value=%{value}<extra></extra>","labels":["Bookcases","Chairs","Labels","Tables","Storage","Furnishings","Art","Phones","Binders","Appliances","Tables","Phones","Paper","Binders","Appliances","Binders","Storage","Storage","Art","Phones","Binders","Art","Appliances","Chairs","Tables","Binders","Accessories","Bookcases","Binders","Furnishings","Envelopes","Art","Binders","Art","Paper",
# ...

# %% [markdown]
# ### The Best Region For Sales

# %%
regions= df.groupby("Region").sum().sort_values("Sales",ascending=False)
regions= regions[['Sales']].round(2)
regions.reset_index(inplace=True)

fig=px.pie(regions,names='Region',values='Sales',title="Regions Sales",color_discrete_sequence=px.colors.sequential.Hot)
fig.show()
# Out:
# <div>                            <div id="6f4eb238-309f-45f9-aa39-57217e67fd76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f4eb238-309f-45f9-aa39-57217e67fd76")) {                    Plotly.newPlot(                        "6f4eb238-309f-45f9-aa39-57217e67fd76",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}<br>Sales=%{value}<extra></extra>","labels":["West","East","Central","South"],"legendgroup":"","name":"","showlegend":true,"values":[710219.68,669518.73,492646.91,389151.46],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222
# ...

# %% [markdown]
# ### The most common category in every city

# %%
plt.figure(figsize=(18,10))
top_cities= df.groupby(["City","Category"]).sum().sort_values("Sales",ascending=False).head(40)
top_cities= top_cities[['Sales']].round(2)
top_cities.reset_index(inplace=True)
sns.barplot(x='City',y='Sales',hue='Category',data=top_cities,palette='dark:salmon_r')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### The most common segment type in every city

# %%
plt.figure(figsize=(18,10))
top_cities= df.groupby(["City","Segment"]).sum().sort_values("Sales",ascending=False).head(40)
top_cities= top_cities[['Sales']].round(2)
top_cities.reset_index(inplace=True)
sns.barplot(x='City',y='Sales',hue='Segment',data=top_cities,palette='dark:salmon_r')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # SIUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUU!!!!!
