# %% [markdown]
# # Import Library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print('Setup Completed!')
# Out:
# /Users/ricardokaizen/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Setup Completed!

# %% [markdown]
# # Import Data 2023:

# %%
master_df1 = pd.read_excel('data_doanhthu_key_2023.xlsx')
master_df1
# Out:
#        Unnamed: 0    Key  Mã CTKM                              Tên CTKM  \
# 0               0  10377   703666   CTKM THÁNG 1 (29/12-26/12)  - 15955
# 1               1  10378   703666   CTKM THÁNG 1 (29/12-26/12)  - 15955
# 2               2  10379   703666   CTKM THÁNG 1 (29/12-26/12)  - 15955
# 3               3  10380   703666   CTKM THÁNG 1 (29/12-26/12)  - 15955
# 4               4  10381   703666   CTKM THÁNG 1 (29/12-26/12)  - 15955
# ...           ...    ...      ...                                   ...
# 94968       94968  70410   731686   CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94969       94969  70419   731686   CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94970       94970  70420   731686   CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94971       94971  70426   731686   CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94972       94972  70433   731686   CTKM THÁNG 3 (03/03-28/03)  - 15955
#
#            CTKM                   Loại chương trình  SL/Số tiền tối thiểu  \
# 0      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 1      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 2      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 3      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 4      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# ...         ...                                 ...                   ...
# 94968  Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94969  Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94970  Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94971  Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94972  Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
#
#        SL/Số tiền tối đa  Tháng bắt đầu KM Ngày bắt đầu  ...  \
# 0                    NaN                 1   2022-12-29  ...
# 1                    NaN                 1   2022-12-29  ...
# 2                    NaN                 1   2022-12-29  ...
# 3                    NaN                 1   2022-12-29  ...
# 4                    NaN                 1   2022-12-29  ...
# ...                  ...               ...          ...  ...
# 94968                NaN                 3   2023-03-03  ...
# 94969                NaN                 3   2023-03-03  ...
# 94970                NaN                 3   2023-03-03  ...
# 94971                NaN                 3   2023-03-03  ...
# 94972                NaN                 3   2023-03-03  ...
#
#       Tỷ lệ tăng trưởng  Cụm lớn C_1st C_2nd C_3rd  Cụm final  Cụm nhỏ  \
# 0              1.399580        0   NaN   NaN   NaN          0    Cụm 0
# 1              0.000000        0   NaN   NaN   NaN          0    Cụm 0
# 2              0.000000        0   NaN   NaN   NaN          0    Cụm 0
# 3              0.000000        0   NaN   NaN   NaN          0    Cụm 0
# 4              0.000000        0   NaN   NaN   NaN          0    Cụm 0
# ...                 ...      ...   ...   ...   ...        ...      ...
# 94968          2.422350        1   1.0   2.0   NaN        112    Cụm 8
# 94969          2.691500        1   1.0   2.0   NaN        112    Cụm 8
# 94970          1.346221        1   1.0   2.0   NaN        112    Cụm 8
# 94971          1.938423        1   1.0   2.0   NaN        112    Cụm 8
# 94972          0.000000        1   1.0   2.0   NaN        112    Cụm 8
#
#        Doanh thu KM  Doanh thu thường  Tổng doanh thu
# 0           39000.0            6859.2         45859.2
# 1               0.0               0.0             0.0
# 2               0.0               0.0             0.0
# 3               0.0               0.0             0.0
# 4               0.0               0.0             0.0
# ...             ...               ...             ...
# 94968      270000.0            6430.5        276430.5
# 94969      300000.0            6430.5        306430.5
# 94970      600000.0           25713.0        625713.0
# 94971     1080000.0           32143.5       1112143.5
# 94972           0.0            6430.5          6430.5
#
# [94973 rows x 74 columns]

# %%
master_df1 = master_df1.drop(columns= 'Unnamed: 0', axis =0)

# %%
master_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94973 entries, 0 to 94972
# Data columns (total 73 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Key                                 94973 non-null  int64
#  1   Mã CTKM                             94973 non-null  int64
#  2   Tên CTKM                            94973 non-null  object
#  3   CTKM                                94973 non-null  object
#  4   Loại chương trình                   94973 non-null  object
#  5   SL/Số tiền tối thiểu                40381 non-null  float64
#  6   SL/Số tiền tối đa                   0 non-null      float64
#  7   Tháng bắt đầu KM                    94973 non-null  int64
#  8   Ngày bắt đầu                        94973 non-null  datetime64[ns]
#  9   Ngày kết thúc                       94973 non-null  datetime64[ns]
#  10  Thời gian khuyến mãi                94973 non-null  int64
#  11  Thời điểm khuyến mãi                94973 non-null  object
#  12  Loại hình thức khuyến mãi           94973 non-null  object
#  13  Áp dụng hình thức khuyến mãi        94973 non-null  object
#  14  Tỷ lệ khuyến mãi                    94973 non-null  float64
#  15  Giá trị KM                          94973 non-null  float64
#  16  Mã SP khuyến mãi tặng/bán kèm       0 non-null      float64
#  17  Số lượng tặng/ bán kèm              0 non-null      float64
#  18  Đơn giá tặng/bán kèm                0 non-null      float64
#  19  Mã SP chính                         94973 non-null  int64
#  20  Model                               94973 non-null  int64
#  21  Số lượng mua tối thiểu              94973 non-null  int64
#  22  Giá bán KV chuẩn                    94973 non-null  int64
#  23  key                                 94973 non-null  object
#  24  Trạng thái kinh doanh               94973 non-null  object
#  25  facing                              94973 non-null  int64
#  26  Tháng-model-st                      94973 non-null  int64
#  27  MST                                 94973 non-null  int64
#  28  Tên ST                              94973 non-null  object
#  29  Miền                                94973 non-null  object
#  30  Tỉnh/thành                          94973 non-null  object
#  31  Quận/huyện                          94973 non-null  object
#  32  Mô hình                             94973 non-null  object
#  33  Thu nhập dân cư quanh shop          94973 non-null  object
#  34  Size shop theo doanh số             94973 non-null  object
#  35  Mức độ cạnh tranh                   94973 non-null  object
#  36  Phân loại mức độ cạnh tranh Fresh   94973 non-null  object
#  37  Phân loại mức độ cạnh tranh FMCG    94973 non-null  object
#  38  Loại ST                             94973 non-null  object
#  39  promoquantity                       94973 non-null  int64
#  40  promoquantity2                      94973 non-null  int64
#  41  nopromoquantity                     94973 non-null  int64
#  42  numdaynostock                       94973 non-null  int64
#  43  numdaynostockitem                   94973 non-null  int64
#  44  numdaystock                         94973 non-null  int64
#  45  clear                               0 non-null      float64
#  46  forecastnopromo                     94973 non-null  float64
#  47  Sức bán thường                      94973 non-null  float64
#  48  Công dụng sản phẩm                  94973 non-null  object
#  49  Có kèm bcdr hay không?              94973 non-null  object
#  50  Brand                               94973 non-null  object
#  51  DVT                                 94973 non-null  object
#  52  Là thương hiệu nổi tiếng hay không  94973 non-null  object
#  53  TE/NL                               94973 non-null  object
#  54  phân loại size                      94973 non-null  object
#  55  Giá bán                             94973 non-null  int64
#  56  Phân loại giá                       94973 non-null  object
#  57  Phân khúc giá                       94973 non-null  object
#  58  Trưng bày                           94973 non-null  object
#  59  Tỷ lệ số ngày tồn = 0 / số ngày KM  94973 non-null  float64
#  60  Phân loại theo st                   94752 non-null  object
#  61  Phân loại theo nhóm                 94973 non-null  object
#  62  TT                                  94973 non-null  float64
#  63  Tỷ lệ tăng trưởng                   94973 non-null  float64
#  64  Cụm lớn                             94973 non-null  int64
#  65  C_1st                               59041 non-null  float64
#  66  C_2nd                               59041 non-null  float64
#  67  C_3rd                               7890 non-null   float64
#  68  Cụm final                           94973 non-null  int64
#  69  Cụm nhỏ                             94973 non-null  object
#  70  Doanh thu KM                        94973 non-null  float64
#  71  Doanh thu thường                    94973 non-null  float64
#  72  Tổng doanh thu                      94973 non-null  float64
# dtypes: datetime64[ns](2), float64(19), int64(20), object(32)
# memory usage: 52.9+ MB

# %%
df1 = master_df1[master_df1['Thời gian khuyến mãi'] <= 30]
df1['Thời gian khuyến mãi'].unique()
# Out:
# array([ 5, 10, 14, 24, 28, 26])

# %%
df1['CTKM'].unique()
# Out:
# array(['Giảm giá', 'Mua 2 tặng 1',
#        '99K Colgate tặng 15k mua thịt, cá, trái cây', '89K P/S tặng 15K'],
#       dtype=object)

# %%
df1 = df1[(df1['CTKM'] == 'Giảm giá') | (df1['CTKM'] == 'Mua 2 tặng 1')]

# %%
df1 = df1[(df1['Là thương hiệu nổi tiếng hay không'] == 'Yes') & (df1['Phân loại giá'] == 'Trung (15K - 25K) NL')]
df1['Phân loại giá'].unique()
# Out:
# array(['Trung (15K - 25K) NL'], dtype=object)

# %%
df1 = df1[(df1['phân loại size'] != 'Nhỏ (<=100g)')]
df1['phân loại size'].unique()
# Out:
# array(['Lớn (>200g)'], dtype=object)

# %%
df1
# Out:
#          Key  Mã CTKM                                           Tên CTKM  \
# 285    53015   720890  CTKM BỔ SUNG THÁNG 1 (03/2-16/02) MUA 2 TẶNG 1...
# 286    53016   720890  CTKM BỔ SUNG THÁNG 1 (03/2-16/02) MUA 2 TẶNG 1...
# 287    53017   720890  CTKM BỔ SUNG THÁNG 1 (03/2-16/02) MUA 2 TẶNG 1...
# 288    53018   720890  CTKM BỔ SUNG THÁNG 1 (03/2-16/02) MUA 2 TẶNG 1...
# 289    53019   720890  CTKM BỔ SUNG THÁNG 1 (03/2-16/02) MUA 2 TẶNG 1...
# ...      ...      ...                                                ...
# 94968  70410   731686                CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94969  70419   731686                CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94970  70420   731686                CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94971  70426   731686                CTKM THÁNG 3 (03/03-28/03)  - 15955
# 94972  70433   731686                CTKM THÁNG 3 (03/03-28/03)  - 15955
#
#                CTKM                   Loại chương trình  SL/Số tiền tối thiểu  \
# 285    Mua 2 tặng 1  Khuyến mãi đích danh theo sản phẩm                   NaN
# 286    Mua 2 tặng 1  Khuyến mãi đích danh theo sản phẩm                   NaN
# 287    Mua 2 tặng 1  Khuyến mãi đích danh theo sản phẩm                   NaN
# 288    Mua 2 tặng 1  Khuyến mãi đích danh theo sản phẩm                   NaN
# 289    Mua 2 tặng 1  Khuyến mãi đích danh theo sản phẩm                   NaN
# ...             ...                                 ...                   ...
# 94968      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94969      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94970      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94971      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
# 94972      Giảm giá  Khuyến mãi đích danh theo sản phẩm                   NaN
#
#        SL/Số tiền tối đa  Tháng bắt đầu KM Ngày bắt đầu Ngày kết thúc  ...  \
# 285                  NaN                 2   2023-02-03    2023-02-16  ...
# 286                  NaN                 2   2023-02-03    2023-02-16  ...
# 287                  NaN                 2   2023-02-03    2023-02-16  ...
# 288                  NaN                 2   2023-02-03    2023-02-16  ...
# 289                  NaN                 2   2023-02-03    2023-02-16  ...
# ...                  ...               ...          ...           ...  ...
# 94968                NaN                 3   2023-03-03    2023-03-28  ...
# 94969                NaN                 3   2023-03-03    2023-03-28  ...
# 94970                NaN                 3   2023-03-03    2023-03-28  ...
# 94971                NaN                 3   2023-03-03    2023-03-28  ...
# 94972                NaN                 3   2023-03-03    2023-03-28  ...
#
#        Tỷ lệ tăng trưởng Cụm lớn C_1st C_2nd  C_3rd  Cụm final  Cụm nhỏ  \
# 285             0.000000       0   NaN   NaN    NaN          0    Cụm 0
# 286             0.000000       0   NaN   NaN    NaN          0    Cụm 0
# 287             0.000000       0   NaN   NaN    NaN          0    Cụm 0
# 288             2.250113       0   NaN   NaN    NaN          0    Cụm 0
# 289             0.499967       0   NaN   NaN    NaN          0    Cụm 0
# ...                  ...     ...   ...   ...    ...        ...      ...
# 94968           2.422350       1   1.0   2.0    NaN        112    Cụm 8
# 94969           2.691500       1   1.0   2.0    NaN        112    Cụm 8
# 94970           1.346221       1   1.0   2.0    NaN        112    Cụm 8
# 94971           1.938423       1   1.0   2.0    NaN        112    Cụm 8
# 94972           0.000000       1   1.0   2.0    NaN        112    Cụm 8
#
#        Doanh thu KM  Doanh thu thường  Tổng doanh thu
# 285             0.0            7002.1          7002.1
# 286             0.0           13999.3         13999.3
# 287             0.0            7002.1          7002.1
# 288        293970.6           13999.3        307969.9
# 289         97990.2           21001.4        118991.6
# ...             ...               ...             ...
# 94968      270000.0            6430.5        276430.5
# 94969      300000.0            6430.5        306430.5
# 94970      600000.0           25713.0        625713.0
# 94971     1080000.0           32143.5       1112143.5
# 94972           0.0            6430.5          6430.5
#
# [34778 rows x 73 columns]

# %%
sum_df1 = df1['Tổng doanh thu'].sum()
sum_df1
# Out:
# 18386462200.780003

# %%
sum_master_df1 = master_df1['Tổng doanh thu'].sum()
sum_master_df1
# Out:
# 28261215451.193222

# %%
data = {'DataFrame': ['Doanh thu hiệu quả', 'Doanh thu tổng'],
        'Tổng doanh thu': [sum_df1, sum_master_df1]}
df = pd.DataFrame(data)
df
# Out:
#             DataFrame  Tổng doanh thu
# 0  Doanh thu hiệu quả    1.838646e+10
# 1      Doanh thu tổng    2.826122e+10

# %%
plt.figure(figsize=(6,6))
plt.title('Tỷ lệ doanh thu hiệu quả 2023')
sns.set_palette('pastel')
sns.set_style('whitegrid')
plt.pie(df['Tổng doanh thu'], labels=df['DataFrame'], autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# # Import Data 2022:

# %%
master_df2 = pd.read_excel('data_2022_key.xlsx', sheet_name= 'Sheet1')
master_df2
# Out:
#            key  Mã CTKM                                           Tên CTKM  \
# 0            0   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 1            1   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 2            2   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 3            3   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 4            4   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# ...        ...      ...                                                ...
# 364742  364742   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364743  364743   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364744  364744   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364745  364745   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364746  364746   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
#
#                                     CTKM  Code CTKM  \
# 0                               Giảm giá          1
# 1                               Giảm giá          1
# 2                               Giảm giá          1
# 3                               Giảm giá          1
# 4                               Giảm giá          1
# ...                                  ...        ...
# 364742  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364743  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364744  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364745  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364746  HĐ P/S 89,000đ được giảm 15,000đ          3
#
#                          Loại chương trình  SL/Số tiền tối thiểu  \
# 0       Khuyến mãi đích danh theo sản phẩm                   NaN
# 1       Khuyến mãi đích danh theo sản phẩm                   NaN
# 2       Khuyến mãi đích danh theo sản phẩm                   NaN
# 3       Khuyến mãi đích danh theo sản phẩm                   NaN
# 4       Khuyến mãi đích danh theo sản phẩm                   NaN
# ...                                    ...                   ...
# 364742       Khuyến mãi tặng tiền mua hàng               89000.0
# 364743       Khuyến mãi tặng tiền mua hàng               89000.0
# 364744       Khuyến mãi tặng tiền mua hàng               89000.0
# 364745       Khuyến mãi tặng tiền mua hàng               89000.0
# 364746       Khuyến mãi tặng tiền mua hàng               89000.0
#
#         SL/Số tiền tối đa Ngày bắt đầu Ngày kết thúc  ...  Sức bán thường  \
# 0                     NaN   2022-03-24    2022-12-28  ...        0.100000
# 1                     NaN   2022-03-24    2022-12-28  ...        0.100000
# 2                     NaN   2022-03-24    2022-12-28  ...        0.100000
# 3                     NaN   2022-03-24    2022-12-28  ...        0.100000
# 4                     NaN   2022-03-24    2022-12-28  ...        0.100000
# ...                   ...          ...           ...  ...             ...
# 364742                NaN   2022-12-28    2023-01-20  ...        0.571400
# 364743                NaN   2022-12-28    2023-01-20  ...        0.333333
# 364744                NaN   2022-12-28    2023-01-20  ...        0.142900
# 364745                NaN   2022-12-28    2023-01-20  ...        0.428600
# 364746                NaN   2022-12-28    2023-01-20  ...        0.285700
#
#        Tỷ lệ số ngày tồn = 0 / số ngày KM Thời điểm khuyến mãi  Doanh thu KM  \
# 0                                0.975000              Dài hạn       68000.0
# 1                                0.971429              Dài hạn       34000.0
# 2                                0.964286              Dài hạn       34000.0
# 3                                0.960714              Dài hạn      136000.0
# 4                                0.960714              Dài hạn       68000.0
# ...                                   ...                  ...           ...
# 364742                           0.000000            Trước tết           0.0
# 364743                           0.000000            Trước tết           0.0
# 364744                           0.000000            Trước tết           0.0
# 364745                           0.000000            Trước tết           0.0
# 364746                           0.000000            Trước tết           0.0
#
#         TT theo doanh thu  Cụm lớn DT  C1  C2  C3  Cụm nhỏ DT
# 0                2.490842       Cụm 0   0   0 NaN       Cụm 0
# 1                1.089744       Cụm 0   0   0 NaN       Cụm 0
# 2                0.871795       Cụm 0   0   0 NaN       Cụm 0
# 3                3.170163       Cụm 0   0   0 NaN       Cụm 0
# 4                1.585082       Cụm 0   0   0 NaN       Cụm 0
# ...                   ...         ...  ..  ..  ..         ...
# 364742           0.000000       Cụm 1   0   0 NaN     Cụm 1.4
# 364743           0.000000       Cụm 1   0   0 NaN     Cụm 1.4
# 364744           0.000000       Cụm 1   0   0 NaN     Cụm 1.4
# 364745           0.000000       Cụm 1   0   0 NaN     Cụm 1.4
# 364746           0.000000       Cụm 1   0   0 NaN     Cụm 1.4
#
# [364747 rows x 65 columns]

# %%
master_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364747 entries, 0 to 364746
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   key                                      364747 non-null  int64
#  1   Mã CTKM                                  364747 non-null  int64
#  2   Tên CTKM                                 364747 non-null  object
#  3   CTKM                                     364747 non-null  object
#  4   Code CTKM                                364747 non-null  int64
#  5   Loại chương trình                        364747 non-null  object
#  6   SL/Số tiền tối thiểu                     76462 non-null   float64
#  7   SL/Số tiền tối đa                        0 non-null       float64
#  8   Ngày bắt đầu                             364747 non-null  datetime64[ns]
#  9   Ngày kết thúc                            364747 non-null  datetime64[ns]
#  10  Thời gian KM                             364747 non-null  int64
#  11  Loại hình thức khuyến mãi                364747 non-null  object
#  12  Áp dụng hình thức khuyến mãi             364747 non-null  object
#  13  Tỷ lệ KM                                 364747 non-null  float64
#  14  Giá trị KM                               290447 non-null  float64
#  15  Mã SP khuyến mãi tặng/bán kèm            74300 non-null   float64
#  16  Số lượng tặng/ bán kèm                   74300 non-null   float64
#  17  Đơn giá tặng/bán kèm                     74300 non-null   float64
#  18  Model                                    364747 non-null  int64
#  19  Mã SP chính                              364747 non-null  int64
#  20  Tên sản phẩm                             364747 non-null  object
#  21  Tên ngành hàng                           364747 non-null  object
#  22  Số lượng mua tối thiểu                   364747 non-null  int64
#  23  Giá bán KV chuẩn                         364747 non-null  int64
#  24  MST                                      364747 non-null  int64
#  25  Tên ST                                   364747 non-null  object
#  26  Miền                                     364747 non-null  object
#  27  Tỉnh/thành                               364747 non-null  object
#  28  Quận/huyện                               364747 non-null  object
#  29  Mô hình                                  364747 non-null  object
#  30  Thu nhập dân cư quanh shop               364747 non-null  object
#  31  Mức độ cạnh tranh                        364747 non-null  object
#  32  Phân loại mức độ cạnh tranh FMCG         364747 non-null  object
#  33  Loại ST                                  364747 non-null  object
#  34  Công dụng sản phẩm                       364747 non-null  object
#  35  Có kèm bcdr hay không?                   364747 non-null  object
#  36  Brand                                    364747 non-null  object
#  37  DVT                                      364747 non-null  object
#  38  Là thương hiệu nổi tiếng hay không       364747 non-null  object
#  39  TE/NL                                    364747 non-null  object
#  40  phân loại size                           364747 non-null  object
#  41  Giá bán                                  364747 non-null  int64
#  42  Phân loại giá                            364747 non-null  object
#  43  Phân khúc giá                            364747 non-null  object
#  44  Label                                    356597 non-null  object
#  45  TTKD                                     364747 non-null  object
#  46  Facing                                   364747 non-null  int64
#  47  Trưng bày                                364747 non-null  object
#  48  Tổng SL bán KM đích danh                 364747 non-null  int64
#  49  Tổng SL bán KM đích danh (2)             364747 non-null  int64
#  50  Tổng SL bán không KM trong thời gian KM  364747 non-null  int64
#  51  Số ngày tồn <=0 trong thời gian KM       364747 non-null  int64
#  52  Sức bán thường 347                       364747 non-null  float64
#  53  Số ngày có tồn trong thời gian KM        364747 non-null  int64
#  54  TT theo số lượng                         364747 non-null  float64
#  55  Sức bán thường                           364747 non-null  float64
#  56  Tỷ lệ số ngày tồn = 0 / số ngày KM       364747 non-null  float64
#  57  Thời điểm khuyến mãi                     364747 non-null  object
#  58  Doanh thu KM                             364747 non-null  float64
#  59  TT theo doanh thu                        364747 non-null  float64
#  60  Cụm lớn DT                               364747 non-null  object
#  61  C1                                       364747 non-null  int64
#  62  C2                                       364747 non-null  int64
#  63  C3                                       249118 non-null  float64
#  64  Cụm nhỏ DT                               364747 non-null  object
# dtypes: datetime64[ns](2), float64(14), int64(18), object(31)
# memory usage: 180.9+ MB

# %%
master_df2['Doanh thu thường'] = master_df2['Sức bán thường'] * master_df2['Giá bán KV chuẩn']
master_df2['Tổng doanh thu'] = master_df2['Doanh thu thường']+ master_df2['Doanh thu KM']
master_df2
# Out:
#            key  Mã CTKM                                           Tên CTKM  \
# 0            0   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 1            1   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 2            2   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 3            3   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# 4            4   462011             CTKM tháng 3  - (24/03-28/12) -  15955
# ...        ...      ...                                                ...
# 364742  364742   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364743  364743   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364744  364744   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364745  364745   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
# 364746  364746   701655  CTKM THÁNG 1 (28/12-20/1) HĐ P/S 89,000đ được ...
#
#                                     CTKM  Code CTKM  \
# 0                               Giảm giá          1
# 1                               Giảm giá          1
# 2                               Giảm giá          1
# 3                               Giảm giá          1
# 4                               Giảm giá          1
# ...                                  ...        ...
# 364742  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364743  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364744  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364745  HĐ P/S 89,000đ được giảm 15,000đ          3
# 364746  HĐ P/S 89,000đ được giảm 15,000đ          3
#
#                          Loại chương trình  SL/Số tiền tối thiểu  \
# 0       Khuyến mãi đích danh theo sản phẩm                   NaN
# 1       Khuyến mãi đích danh theo sản phẩm                   NaN
# 2       Khuyến mãi đích danh theo sản phẩm                   NaN
# 3       Khuyến mãi đích danh theo sản phẩm                   NaN
# 4       Khuyến mãi đích danh theo sản phẩm                   NaN
# ...                                    ...                   ...
# 364742       Khuyến mãi tặng tiền mua hàng               89000.0
# 364743       Khuyến mãi tặng tiền mua hàng               89000.0
# 364744       Khuyến mãi tặng tiền mua hàng               89000.0
# 364745       Khuyến mãi tặng tiền mua hàng               89000.0
# 364746       Khuyến mãi tặng tiền mua hàng               89000.0
#
#         SL/Số tiền tối đa Ngày bắt đầu Ngày kết thúc  ...  \
# 0                     NaN   2022-03-24    2022-12-28  ...
# 1                     NaN   2022-03-24    2022-12-28  ...
# 2                     NaN   2022-03-24    2022-12-28  ...
# 3                     NaN   2022-03-24    2022-12-28  ...
# 4                     NaN   2022-03-24    2022-12-28  ...
# ...                   ...          ...           ...  ...
# 364742                NaN   2022-12-28    2023-01-20  ...
# 364743                NaN   2022-12-28    2023-01-20  ...
# 364744                NaN   2022-12-28    2023-01-20  ...
# 364745                NaN   2022-12-28    2023-01-20  ...
# 364746                NaN   2022-12-28    2023-01-20  ...
#
#         Thời điểm khuyến mãi Doanh thu KM TT theo doanh thu  Cụm lớn DT  C1  \
# 0                    Dài hạn      68000.0          2.490842       Cụm 0   0
# 1                    Dài hạn      34000.0          1.089744       Cụm 0   0
# 2                    Dài hạn      34000.0          0.871795       Cụm 0   0
# 3                    Dài hạn     136000.0          3.170163       Cụm 0   0
# 4                    Dài hạn      68000.0          1.585082       Cụm 0   0
# ...                      ...          ...               ...         ...  ..
# 364742             Trước tết          0.0          0.000000       Cụm 1   0
# 364743             Trước tết          0.0          0.000000       Cụm 1   0
# 364744             Trước tết          0.0          0.000000       Cụm 1   0
# 364745             Trước tết          0.0          0.000000       Cụm 1   0
# 364746             Trước tết          0.0          0.000000       Cụm 1   0
#
#         C2  C3  Cụm nhỏ DT  Doanh thu thường  Tổng doanh thu
# 0        0 NaN       Cụm 0            3900.0         71900.0
# 1        0 NaN       Cụm 0            3900.0         37900.0
# 2        0 NaN       Cụm 0            3900.0         37900.0
# 3        0 NaN       Cụm 0            3900.0        139900.0
# 4        0 NaN       Cụm 0            3900.0         71900.0
# ...     ..  ..         ...               ...             ...
# 364742   0 NaN     Cụm 1.4           10285.2         10285.2
# 364743   0 NaN     Cụm 1.4            6000.0          6000.0
# 364744   0 NaN     Cụm 1.4            2572.2          2572.2
# 364745   0 NaN     Cụm 1.4            7714.8          7714.8
# 364746   0 NaN     Cụm 1.4            5142.6          5142.6
#
# [364747 rows x 67 columns]

# %%
sum_master_df2 = master_df2['Tổng doanh thu'].sum()
sum_master_df2
# Out:
# 89981652123.32722

# %%
df2 = master_df2[master_df2['Thời gian KM'] <= 30]
df2['Thời gian KM'].unique()
# Out:
# array([28, 27, 26, 24, 30, 20, 19, 16, 15, 14, 13, 12, 11, 10,  7,  9,  6,
#         4,  5,  3,  2,  1])

# %%
df2 = df2[(df2['CTKM'] == 'Giảm giá') | (df2['CTKM'] == 'Tặng quà - Mua 2 tặng 1')]
df2['CTKM'].unique()
# Out:
# array(['Giảm giá', 'Tặng quà - Mua 2 tặng 1'], dtype=object)

# %%
df2 = df2[(df2['Là thương hiệu nổi tiếng hay không'] == 'Yes') & (df2['Phân loại giá'] == 'Trung (15K - 25K) NL')]
df2['Phân loại giá'].unique()
# Out:
# array(['Trung (15K - 25K) NL'], dtype=object)

# %%
df2 = df2[(df2['phân loại size'] != 'Nhỏ (<=100g)')]
df2['phân loại size'].unique()
# Out:
# array(['Lớn (>200g)', 'Vừa (100g-200g)'], dtype=object)

# %%
sum_df2 = df2['Tổng doanh thu'].sum()
sum_df2
# Out:
# 51348491136.05529

# %%
data = {'DataFrame': ['Doanh thu hiệu quả', 'Doanh thu tổng'],
        'Tổng doanh thu': [sum_df2, sum_master_df2]}
df_2 = pd.DataFrame(data)
df_2
# Out:
#             DataFrame  Tổng doanh thu
# 0  Doanh thu hiệu quả    5.134849e+10
# 1      Doanh thu tổng    8.998165e+10

# %%
plt.figure(figsize=(6,6))
plt.title('Tỷ lệ doanh thu hiệu quả 2022')
sns.set_palette('pastel')
sns.set_style('whitegrid')
plt.pie(df_2['Tổng doanh thu'], labels=df_2['DataFrame'], autopct='%1.1f%%')
plt.legend()
plt.show();

# %% [markdown]
# # Phân tích đặc điểm số lượng CTKM hiệu quả năm 2022 và năm 2023:

# %% [markdown]
# ## 2022

# %%
df_ctkm_2022 = df2[['Mã CTKM','CTKM','Tổng doanh thu']]
df_ctkm_2022
# Out:
#         Mã CTKM      CTKM  Tổng doanh thu
# 7220     396204  Giảm giá    64358.600000
# 7221     396204  Giảm giá    48444.050000
# 7224     396090  Giảm giá    57787.000000
# 7225     396089  Giảm giá   466592.571429
# 7245     449902  Giảm giá    49359.200000
# ...         ...       ...             ...
# 296273   593032  Giảm giá   155716.000000
# 296274   593032  Giảm giá   215714.285714
# 296275   593032  Giảm giá   347144.000000
# 296276   593032  Giảm giá   131428.000000
# 296277   593032  Giảm giá    64000.000000
#
# [174549 rows x 3 columns]

# %%
df_ctkm_2022 = df_ctkm_2022.groupby(['Mã CTKM','CTKM'])['Tổng doanh thu'].sum()
df_ctkm_2022 = df_ctkm_2022.reset_index()
df_ctkm_2022
# Out:
#      Mã CTKM                     CTKM  Tổng doanh thu
# 0     396089                 Giảm giá    7.230525e+08
# 1     396090                 Giảm giá    3.796253e+08
# 2     396198                 Giảm giá    3.729446e+08
# 3     396201                 Giảm giá    2.766244e+08
# 4     396204                 Giảm giá    1.262348e+08
# ..       ...                      ...             ...
# 128   704784  Tặng quà - Mua 2 tặng 1    6.103242e+08
# 129   704788                 Giảm giá    5.158171e+08
# 130   704789                 Giảm giá    2.370517e+08
# 131   704790                 Giảm giá    9.249491e+08
# 132   705473  Tặng quà - Mua 2 tặng 1    4.472959e+07
#
# [133 rows x 3 columns]

# %%
df_count_ctkm_2022 = df_ctkm_2022.groupby('CTKM')['Mã CTKM'].count()
df_count_ctkm_2022 = df_count_ctkm_2022.reset_index()
df_count_ctkm_2022
# Out:
#                       CTKM  Mã CTKM
# 0                 Giảm giá       83
# 1  Tặng quà - Mua 2 tặng 1       50

# %%
plt.pie(df_count_ctkm_2022['Mã CTKM'], labels=df_count_ctkm_2022['CTKM'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ số lượng CTKM hiệu quả 2022')
plt.legend()
plt.show();

# %%
df_sum_ctkm_2022 = df_ctkm_2022.groupby('CTKM')['Tổng doanh thu'].sum()
df_sum_ctkm_2022 = df_sum_ctkm_2022.reset_index()
df_sum_ctkm_2022
# Out:
#                       CTKM  Tổng doanh thu
# 0                 Giảm giá    3.832688e+10
# 1  Tặng quà - Mua 2 tặng 1    1.302161e+10

# %%
plt.pie(df_sum_ctkm_2022['Tổng doanh thu'], labels=df_sum_ctkm_2022['CTKM'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ doanh thu CTKM hiệu quả 2022')
plt.legend()
plt.show();

# %% [markdown]
# ## 2023:

# %%
df_ctkm_2023 = df1[['Mã CTKM','CTKM','Tổng doanh thu']]
df_ctkm_2023
# Out:
#        Mã CTKM          CTKM  Tổng doanh thu
# 285     720890  Mua 2 tặng 1          7002.1
# 286     720890  Mua 2 tặng 1         13999.3
# 287     720890  Mua 2 tặng 1          7002.1
# 288     720890  Mua 2 tặng 1        307969.9
# 289     720890  Mua 2 tặng 1        118991.6
# ...        ...           ...             ...
# 94968   731686      Giảm giá        276430.5
# 94969   731686      Giảm giá        306430.5
# 94970   731686      Giảm giá        625713.0
# 94971   731686      Giảm giá       1112143.5
# 94972   731686      Giảm giá          6430.5
#
# [34778 rows x 3 columns]

# %%
df_ctkm_2023 = df_ctkm_2023.groupby(['Mã CTKM','CTKM'])['Tổng doanh thu'].sum()
df_ctkm_2023 = df_ctkm_2023.reset_index()
df_ctkm_2023
# Out:
#     Mã CTKM          CTKM  Tổng doanh thu
# 0    701714  Mua 2 tặng 1    2.872785e+08
# 1    701715  Mua 2 tặng 1    3.667622e+08
# 2    703452      Giảm giá    1.504834e+09
# 3    703453      Giảm giá    1.090595e+09
# 4    703696      Giảm giá    1.211222e+09
# 5    703697      Giảm giá    1.181745e+09
# 6    704784  Mua 2 tặng 1    5.992810e+08
# 7    704788      Giảm giá    5.192306e+08
# 8    704789      Giảm giá    2.387425e+08
# 9    704790      Giảm giá    9.271436e+08
# 10   717747      Giảm giá    9.557144e+08
# 11   720890  Mua 2 tặng 1    1.906758e+08
# 12   726226  Mua 2 tặng 1    7.025174e+07
# 13   731553      Giảm giá    4.402150e+08
# 14   731554      Giảm giá    2.424433e+08
# 15   731555      Giảm giá    1.034366e+08
# 16   731684      Giảm giá    2.955343e+08
# 17   731686      Giảm giá    2.725946e+09
# 18   731687      Giảm giá    2.934567e+09
# 19   731688      Giảm giá    1.584835e+09
# 20   732031      Giảm giá    3.723921e+08
# 21   732032      Giảm giá    2.130504e+08
# 22   732033      Giảm giá    8.522608e+07
# 23   732034      Giảm giá    2.453403e+08

# %%
df_count_ctkm_2023 = df_ctkm_2023.groupby('CTKM')['Mã CTKM'].count()
df_count_ctkm_2023 = df_count_ctkm_2023.reset_index()
df_count_ctkm_2023
# Out:
#            CTKM  Mã CTKM
# 0      Giảm giá       19
# 1  Mua 2 tặng 1        5

# %%
plt.pie(df_count_ctkm_2023['Mã CTKM'], labels=df_count_ctkm_2023['CTKM'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ số lượng CTKM hiệu quả 2023')
plt.legend()
plt.show();

# %%
df_sum_ctkm_2023 = df_ctkm_2023.groupby('CTKM')['Tổng doanh thu'].sum()
df_sum_ctkm_2023 = df_sum_ctkm_2023.reset_index()
df_sum_ctkm_2023
# Out:
#            CTKM  Tổng doanh thu
# 0      Giảm giá    1.687221e+10
# 1  Mua 2 tặng 1    1.514249e+09

# %%
plt.pie(df_sum_ctkm_2023['Tổng doanh thu'], labels=df_sum_ctkm_2023['CTKM'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ doanh thu CTKM hiệu quả 2023')
plt.legend()
plt.show();

# %% [markdown]
# # Phân tích đặc điểm trưng bày CTKM hiệu quả của năm 2022 và 2023:

# %% [markdown]
# ## 2022:

# %%
df_trungbay_2022 = df2[['Mã CTKM','Trưng bày','Tổng doanh thu']]
df_trungbay_2022
# Out:
#         Mã CTKM Trưng bày  Tổng doanh thu
# 7220     396204   Trên kệ    64358.600000
# 7221     396204   Trên kệ    48444.050000
# 7224     396090   Trên kệ    57787.000000
# 7225     396089   Trên kệ   466592.571429
# 7245     449902   Trên kệ    49359.200000
# ...         ...       ...             ...
# 296273   593032   Trên kệ   155716.000000
# 296274   593032   Trên kệ   215714.285714
# 296275   593032   Trên kệ   347144.000000
# 296276   593032   Trên kệ   131428.000000
# 296277   593032   Trên kệ    64000.000000
#
# [174549 rows x 3 columns]

# %%
df_trungbay_2022 = df_trungbay_2022.groupby(['Mã CTKM','Trưng bày'])['Tổng doanh thu'].sum()
df_trungbay_2022 = df_trungbay_2022.reset_index()
df_trungbay_2022
# Out:
#      Mã CTKM Trưng bày  Tổng doanh thu
# 0     396089   Trên kệ    7.230525e+08
# 1     396090   Trên kệ    3.796253e+08
# 2     396198   Trên kệ    3.729446e+08
# 3     396201   Trên kệ    2.766244e+08
# 4     396204   Trên kệ    1.262348e+08
# ..       ...       ...             ...
# 128   704784    Ụ tháp    6.103242e+08
# 129   704788   Trên kệ    5.158171e+08
# 130   704789   Trên kệ    2.370517e+08
# 131   704790   Trên kệ    9.249491e+08
# 132   705473    Ụ tháp    4.472959e+07
#
# [133 rows x 3 columns]

# %%
df_count_trungbay_2022 = df_trungbay_2022.groupby('Trưng bày')['Mã CTKM'].count()
df_count_trungbay_2022 = df_count_trungbay_2022.reset_index()
df_count_trungbay_2022
# Out:
#   Trưng bày  Mã CTKM
# 0  Thu ngân        4
# 1   Trên kệ       91
# 2    Ụ tháp       38

# %%
plt.pie(df_count_trungbay_2022['Mã CTKM'], labels=df_count_trungbay_2022['Trưng bày'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ số lượng CTKM trưng bày hiệu quả 2022')
plt.legend()
plt.show();

# %%
df_sum_trungbay_2022 = df_trungbay_2022.groupby('Trưng bày')['Tổng doanh thu'].sum()
df_sum_trungbay_2022 = df_sum_trungbay_2022.reset_index()
df_sum_trungbay_2022
# Out:
#   Trưng bày  Tổng doanh thu
# 0  Thu ngân    1.018978e+09
# 1   Trên kệ    3.800111e+10
# 2    Ụ tháp    1.232841e+10

# %%
plt.pie(df_sum_trungbay_2022['Tổng doanh thu'], labels=df_sum_trungbay_2022['Trưng bày'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ doanh thu CTKM trưng bày hiệu quả 2022')
plt.legend()
plt.show();

# %% [markdown]
# ## 2023:

# %%
df_trungbay_2023 = df1[['Mã CTKM','Trưng bày','Tổng doanh thu']]
df_trungbay_2023
# Out:
#        Mã CTKM Trưng bày  Tổng doanh thu
# 285     720890   Tháp KM          7002.1
# 286     720890   Tháp KM         13999.3
# 287     720890   Tháp KM          7002.1
# 288     720890   Tháp KM        307969.9
# 289     720890   Tháp KM        118991.6
# ...        ...       ...             ...
# 94968   731686   Tháp KM        276430.5
# 94969   731686   Tháp KM        306430.5
# 94970   731686   Tháp KM        625713.0
# 94971   731686   Tháp KM       1112143.5
# 94972   731686   Tháp KM          6430.5
#
# [34778 rows x 3 columns]

# %%
df_trungbay_2023 = df_trungbay_2023.groupby(['Mã CTKM','Trưng bày'])['Tổng doanh thu'].sum()
df_trungbay_2023 = df_trungbay_2023.reset_index()
df_trungbay_2023
# Out:
#     Mã CTKM Trưng bày  Tổng doanh thu
# 0    701714   Tháp KM    2.872785e+08
# 1    701715   Tháp KM    3.667622e+08
# 2    703452   Trên kệ    1.504834e+09
# 3    703453   Trên kệ    1.090595e+09
# 4    703696   Trên kệ    1.211222e+09
# 5    703697   Trên kệ    1.181745e+09
# 6    704784   Tháp KM    5.992810e+08
# 7    704788   Trên kệ    5.192306e+08
# 8    704789   Trên kệ    2.387425e+08
# 9    704790   Trên kệ    9.271436e+08
# 10   717747   Trên kệ    9.557144e+08
# 11   720890   Tháp KM    1.906758e+08
# 12   726226   Trên kệ    7.025174e+07
# 13   731553   Trên kệ    4.402150e+08
# 14   731554   Trên kệ    2.424433e+08
# 15   731555   Trên kệ    1.034366e+08
# 16   731684   Trên kệ    2.955343e+08
# 17   731686   Tháp KM    2.725946e+09
# 18   731687   Tháp KM    2.934567e+09
# 19   731688   Tháp KM    1.584835e+09
# 20   732031   Trên kệ    3.723921e+08
# 21   732032   Trên kệ    2.130504e+08
# 22   732033   Trên kệ    8.522608e+07
# 23   732034   Trên kệ    2.453403e+08

# %%
df_count_trungbay_2023 = df_trungbay_2023.groupby('Trưng bày')['Mã CTKM'].count()
df_count_trungbay_2023 = df_count_trungbay_2023.reset_index()
df_count_trungbay_2023
# Out:
#   Trưng bày  Mã CTKM
# 0   Tháp KM        7
# 1   Trên kệ       17

# %%
plt.pie(df_count_trungbay_2023['Mã CTKM'], labels=df_count_trungbay_2023['Trưng bày'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ số lượng CTKM trưng bày hiệu quả 2023')
plt.legend()
plt.show();

# %%
df_sum_trungbay_2023 = df_trungbay_2023.groupby('Trưng bày')['Tổng doanh thu'].sum()
df_sum_trungbay_2023 = df_sum_trungbay_2023.reset_index()
df_sum_trungbay_2023
# Out:
#   Trưng bày  Tổng doanh thu
# 0   Tháp KM    8.689345e+09
# 1   Trên kệ    9.697118e+09

# %%
plt.pie(df_sum_trungbay_2023['Tổng doanh thu'], labels=df_sum_trungbay_2023['Trưng bày'], autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ doanh thu CTKM trưng bày hiệu quả 2023')
plt.legend()
plt.show();

# %% [markdown]
# # Phân tích thời gian khuyến mãi và tổng doanh thu theo CTKM vào năm 2022 và 2023 hiệu quả:

# %% [markdown]
# ## 2022:

# %%
df_thoigian_2022 = df2[['Mã CTKM', 'CTKM', 'Thời gian KM','Tổng doanh thu']]
df_thoigian_2022
# Out:
#         Mã CTKM      CTKM  Thời gian KM  Tổng doanh thu
# 7220     396204  Giảm giá            28    64358.600000
# 7221     396204  Giảm giá            28    48444.050000
# 7224     396090  Giảm giá            28    57787.000000
# 7225     396089  Giảm giá            28   466592.571429
# 7245     449902  Giảm giá            28    49359.200000
# ...         ...       ...           ...             ...
# 296273   593032  Giảm giá            14   155716.000000
# 296274   593032  Giảm giá            14   215714.285714
# 296275   593032  Giảm giá            14   347144.000000
# 296276   593032  Giảm giá            14   131428.000000
# 296277   593032  Giảm giá            14    64000.000000
#
# [174549 rows x 4 columns]

# %%
df_thoigian_2022 = df_thoigian_2022.groupby(['Mã CTKM','CTKM','Thời gian KM'])['Tổng doanh thu'].sum().reset_index()
df_thoigian_2022
# Out:
#      Mã CTKM                     CTKM  Thời gian KM  Tổng doanh thu
# 0     396089                 Giảm giá            28    7.230525e+08
# 1     396090                 Giảm giá            28    3.796253e+08
# 2     396198                 Giảm giá            28    3.729446e+08
# 3     396201                 Giảm giá            28    2.766244e+08
# 4     396204                 Giảm giá            28    1.262348e+08
# ..       ...                      ...           ...             ...
# 128   704784  Tặng quà - Mua 2 tặng 1            24    6.103242e+08
# 129   704788                 Giảm giá            24    5.158171e+08
# 130   704789                 Giảm giá            24    2.370517e+08
# 131   704790                 Giảm giá            24    9.249491e+08
# 132   705473  Tặng quà - Mua 2 tặng 1             2    4.472959e+07
#
# [133 rows x 4 columns]

# %%
ax = sns.barplot(df_thoigian_2022, x = 'Thời gian KM', y = 'Tổng doanh thu', hue = 'CTKM')
plt.title('Biểu đồ tổng doanh thu và thời gian khuyến mãi theo CTKM 2022')
plt.show();

# %% [markdown]
# ## 2023:

# %%
df_thoigian_2023 = df1[['Mã CTKM', 'CTKM', 'Thời gian khuyến mãi','Tổng doanh thu']]
df_thoigian_2023
# Out:
#        Mã CTKM          CTKM  Thời gian khuyến mãi  Tổng doanh thu
# 285     720890  Mua 2 tặng 1                    14          7002.1
# 286     720890  Mua 2 tặng 1                    14         13999.3
# 287     720890  Mua 2 tặng 1                    14          7002.1
# 288     720890  Mua 2 tặng 1                    14        307969.9
# 289     720890  Mua 2 tặng 1                    14        118991.6
# ...        ...           ...                   ...             ...
# 94968   731686      Giảm giá                    26        276430.5
# 94969   731686      Giảm giá                    26        306430.5
# 94970   731686      Giảm giá                    26        625713.0
# 94971   731686      Giảm giá                    26       1112143.5
# 94972   731686      Giảm giá                    26          6430.5
#
# [34778 rows x 4 columns]

# %%
df_thoigian_2023 = df_thoigian_2023.groupby(['Mã CTKM','CTKM', 'Thời gian khuyến mãi'])['Tổng doanh thu'].sum().reset_index().sort_values(by = 'CTKM')
df_thoigian_2023
# Out:
#     Mã CTKM          CTKM  Thời gian khuyến mãi  Tổng doanh thu
# 23   732034      Giảm giá                    14    2.453403e+08
# 16   731684      Giảm giá                    14    2.955343e+08
# 15   731555      Giảm giá                    14    1.034366e+08
# 14   731554      Giảm giá                    14    2.424433e+08
# 13   731553      Giảm giá                    14    4.402150e+08
# 19   731688      Giảm giá                    26    1.584835e+09
# 22   732033      Giảm giá                    14    8.522608e+07
# 10   717747      Giảm giá                    14    9.557144e+08
# 17   731686      Giảm giá                    26    2.725946e+09
# 9    704790      Giảm giá                    24    9.271436e+08
# 7    704788      Giảm giá                    24    5.192306e+08
# 20   732031      Giảm giá                    14    3.723921e+08
# 5    703697      Giảm giá                    24    1.181745e+09
# 4    703696      Giảm giá                    24    1.211222e+09
# 3    703453      Giảm giá                    24    1.090595e+09
# 2    703452      Giảm giá                    24    1.504834e+09
# 21   732032      Giảm giá                    14    2.130504e+08
# 8    704789      Giảm giá                    24    2.387425e+08
# 18   731687      Giảm giá                    26    2.934567e+09
# 0    701714  Mua 2 tặng 1                    24    2.872785e+08
# 6    704784  Mua 2 tặng 1                    24    5.992810e+08
# 1    701715  Mua 2 tặng 1                    24    3.667622e+08
# 12   726226  Mua 2 tặng 1                    14    7.025174e+07
# 11   720890  Mua 2 tặng 1                    14    1.906758e+08

# %%
ax = sns.barplot(df_thoigian_2023, x = 'Thời gian khuyến mãi', y = 'Tổng doanh thu', hue = 'CTKM')
plt.title('Biểu đồ tổng doanh thu và thời gian khuyến mãi theo CTKM 2023')
plt.show();

# %% [markdown]
# # Phân tích thời gian khuyến mãi và tổng doanh thu theo trưng bày vào năm 2022 và 2023 hiệu quả:

# %% [markdown]
# ## 2022:

# %%
df_thoigian_trungbay_2022 = df2[['Mã CTKM', 'Trưng bày', 'Thời gian KM','Tổng doanh thu']]
df_thoigian_trungbay_2022
# Out:
#         Mã CTKM Trưng bày  Thời gian KM  Tổng doanh thu
# 7220     396204   Trên kệ            28    64358.600000
# 7221     396204   Trên kệ            28    48444.050000
# 7224     396090   Trên kệ            28    57787.000000
# 7225     396089   Trên kệ            28   466592.571429
# 7245     449902   Trên kệ            28    49359.200000
# ...         ...       ...           ...             ...
# 296273   593032   Trên kệ            14   155716.000000
# 296274   593032   Trên kệ            14   215714.285714
# 296275   593032   Trên kệ            14   347144.000000
# 296276   593032   Trên kệ            14   131428.000000
# 296277   593032   Trên kệ            14    64000.000000
#
# [174549 rows x 4 columns]

# %%
df_thoigian_trungbay_2022 = df_thoigian_trungbay_2022.groupby(['Mã CTKM','Trưng bày','Thời gian KM'])['Tổng doanh thu'].sum().reset_index()
df_thoigian_trungbay_2022
# Out:
#      Mã CTKM Trưng bày  Thời gian KM  Tổng doanh thu
# 0     396089   Trên kệ            28    7.230525e+08
# 1     396090   Trên kệ            28    3.796253e+08
# 2     396198   Trên kệ            28    3.729446e+08
# 3     396201   Trên kệ            28    2.766244e+08
# 4     396204   Trên kệ            28    1.262348e+08
# ..       ...       ...           ...             ...
# 128   704784    Ụ tháp            24    6.103242e+08
# 129   704788   Trên kệ            24    5.158171e+08
# 130   704789   Trên kệ            24    2.370517e+08
# 131   704790   Trên kệ            24    9.249491e+08
# 132   705473    Ụ tháp             2    4.472959e+07
#
# [133 rows x 4 columns]

# %%
ax = sns.barplot(df_thoigian_trungbay_2022, x = 'Thời gian KM', y = 'Tổng doanh thu', hue = 'Trưng bày')
plt.title('Biểu đồ tổng doanh thu và thời gian khuyến mãi theo trưng bày 2022')
plt.show();

# %% [markdown]
# ## 2023:

# %%
df_thoigian_trungbay_2023 = df1[['Mã CTKM', 'Trưng bày', 'Thời gian khuyến mãi','Tổng doanh thu']]
df_thoigian_trungbay_2023
# Out:
#        Mã CTKM Trưng bày  Thời gian khuyến mãi  Tổng doanh thu
# 285     720890   Tháp KM                    14          7002.1
# 286     720890   Tháp KM                    14         13999.3
# 287     720890   Tháp KM                    14          7002.1
# 288     720890   Tháp KM                    14        307969.9
# 289     720890   Tháp KM                    14        118991.6
# ...        ...       ...                   ...             ...
# 94968   731686   Tháp KM                    26        276430.5
# 94969   731686   Tháp KM                    26        306430.5
# 94970   731686   Tháp KM                    26        625713.0
# 94971   731686   Tháp KM                    26       1112143.5
# 94972   731686   Tháp KM                    26          6430.5
#
# [34778 rows x 4 columns]

# %%
df_thoigian_trungbay_2023 = df_thoigian_trungbay_2023.groupby(['Mã CTKM','Trưng bày','Thời gian khuyến mãi'])['Tổng doanh thu'].sum().reset_index()
df_thoigian_trungbay_2023
# Out:
#     Mã CTKM Trưng bày  Thời gian khuyến mãi  Tổng doanh thu
# 0    701714   Tháp KM                    24    2.872785e+08
# 1    701715   Tháp KM                    24    3.667622e+08
# 2    703452   Trên kệ                    24    1.504834e+09
# 3    703453   Trên kệ                    24    1.090595e+09
# 4    703696   Trên kệ                    24    1.211222e+09
# 5    703697   Trên kệ                    24    1.181745e+09
# 6    704784   Tháp KM                    24    5.992810e+08
# 7    704788   Trên kệ                    24    5.192306e+08
# 8    704789   Trên kệ                    24    2.387425e+08
# 9    704790   Trên kệ                    24    9.271436e+08
# 10   717747   Trên kệ                    14    9.557144e+08
# 11   720890   Tháp KM                    14    1.906758e+08
# 12   726226   Trên kệ                    14    7.025174e+07
# 13   731553   Trên kệ                    14    4.402150e+08
# 14   731554   Trên kệ                    14    2.424433e+08
# 15   731555   Trên kệ                    14    1.034366e+08
# 16   731684   Trên kệ                    14    2.955343e+08
# 17   731686   Tháp KM                    26    2.725946e+09
# 18   731687   Tháp KM                    26    2.934567e+09
# 19   731688   Tháp KM                    26    1.584835e+09
# 20   732031   Trên kệ                    14    3.723921e+08
# 21   732032   Trên kệ                    14    2.130504e+08
# 22   732033   Trên kệ                    14    8.522608e+07
# 23   732034   Trên kệ                    14    2.453403e+08

# %%
ax = sns.barplot(df_thoigian_trungbay_2023, x = 'Thời gian khuyến mãi', y = 'Tổng doanh thu', hue = 'Trưng bày')
plt.title('Biểu đồ tổng doanh thu và thời gian khuyến mãi theo trưng bày 2023')
plt.show();

# %% [markdown]
# # Task 3: SKU

# %% [markdown]
# ## 2022:

# %%
df_sku_2022 = master_df2[['Mã SP chính', 'Tên sản phẩm', 'TT theo số lượng']]
df_sku_2022
# Out:
#           Mã SP chính                                     Tên sản phẩm  \
# 0       9252712000363  KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG TÁO 80G
# 1       9252712000363  KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG TÁO 80G
# 2       9252712000363  KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG TÁO 80G
# 3       9252712000363  KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG TÁO 80G
# 4       9252712000363  KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG TÁO 80G
# ...               ...                                              ...
# 364742  9252836000183        KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
# 364743  9252836000183        KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
# 364744  9252836000183        KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
# 364745  9252836000183        KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
# 364746  9252836000183        KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
#
#         TT theo số lượng
# 0               2.857143
# 1               1.250000
# 2               1.000000
# 3               3.636364
# 4               1.818182
# ...                  ...
# 364742          0.875044
# 364743          1.500000
# 364744          4.373688
# 364745          0.291647
# 364746          0.583363
#
# [364747 rows x 3 columns]

# %%
df_sku_2022 = df_sku_2022.groupby(['Mã SP chính', 'Tên sản phẩm'])['TT theo số lượng'].mean().reset_index()
df_sku_2022
# Out:
#       Mã SP chính                                       Tên sản phẩm  \
# 0   8934839103903      KEM ĐÁNH RĂNG P/S BÉ NGOAN 35G (TRẺ EM H.DÂU)
# 1   8934839121686            KEM ĐÁNH RĂNG CLOSEUP HƯƠNG BẠC HÀ 230G
# 2   8934839121723     KEM ĐÁNH RĂNG CLOSEUP TINH THỂ BĂNG TUYẾT 230G
# 3   8935102105754                       KDR COLGATE OPTIC WHITE 100G
# 4   8935102105860              KDR COLGATE MAXFRESH BẠC HÀ 200G/180G
# ..            ...                                                ...
# 56  9252836000012  KDR COLGATE NGUA SAU RANG TOI DA 250G/225G + B...
# 57  9252836000039           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 240G/230G
# 58  9252836000043         KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 100G/60 ỐNG
# 59  9252836000044  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 60  9252836000183          KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
#
#     TT theo số lượng
# 0           1.720914
# 1           3.288018
# 2           3.804348
# 3           1.413121
# 4           1.572488
# ..               ...
# 56          7.314093
# 57          4.007505
# 58          1.463675
# 59          2.317388
# 60          1.454147
#
# [61 rows x 3 columns]

# %%
df_sku_2022_hq = df_sku_2022[df_sku_2022['TT theo số lượng'] >= 1.0]
df_sku_2022_hq
# Out:
#       Mã SP chính                                       Tên sản phẩm  \
# 0   8934839103903      KEM ĐÁNH RĂNG P/S BÉ NGOAN 35G (TRẺ EM H.DÂU)
# 1   8934839121686            KEM ĐÁNH RĂNG CLOSEUP HƯƠNG BẠC HÀ 230G
# 2   8934839121723     KEM ĐÁNH RĂNG CLOSEUP TINH THỂ BĂNG TUYẾT 230G
# 3   8935102105754                       KDR COLGATE OPTIC WHITE 100G
# 4   8935102105860              KDR COLGATE MAXFRESH BẠC HÀ 200G/180G
# 5   8935102105891  KEM ĐÁNH RĂNG COLGATE MAXFRESH TRÀ XANH 200G/180G
# 6   9252712000007  KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG VƯỢT TRỘI 240G...
# 7   9252712000018           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 190G/180G
# 8   9252712000019  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 9   9252712000029  KEM ĐÁNH RĂNG BẢO VỆ 1 2 3/ TRẮNG RĂNG THAN HO...
# 10  9252712000040                   KĐR Colgate Natural Seaweed 180g
# 11  9252712000043            KDR COLGATE MAXFRESH BẠC HÀ 230G + BCDR
# 12  9252712000044  KDR COLGATE MAXFRESH THỔI BÙNG SẢNG KHOÁI 230G...
# 15  9252712000066                KDR CLOSEUP DỪA THAN HOẠT TÍNH 180G
# 16  9252712000069         Kem Đánh Răng Col Muối Thảo Dược 250G/225G
# 17  9252712000077          KDR COLGATE MAXFRESH TRÀ XANH 230G + BCDR
# 18  9252712000084   KEM ĐÁNH RĂNG P/S TRẮNG RĂNG THAN HOẠT TÍNH 230G
# 19  9252712000094    KĐR CLOSE UP THƠM MÁT DÂU QUẤT & THẢO DƯỢC 180G
# 20  9252712000111   KDR COLGATE TOTAL CHARCOAL DEEP CLEAN 190g/ 170g
# 24  9252712000169                KĐR COLGATE THAN TRE VÀ BẠC HÀ 180G
# 25  9252712000172  KEM ĐÁNH RĂNG TRẺ EM COLGATE MINION 80G/MILD M...
# 26  9252712000174                       KĐR TRẺ EM COLGATE TIGER 40G
# 29  9252712000203  BỘ 2 KEM ĐÁNH RĂNG COLGATE MAXFRESH HƯƠNG BẠC ...
# 30  9252712000214  KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 225G +...
# 31  9252712000215       KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 200G
# 32  9252712000218    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 180G
# 33  9252712000219    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 230G
# 34  9252712000260        KEM ĐÁNH RĂNG P/S SENSITIVE FRESH MINT 100G
# 35  9252712000261         KEM ĐÁNH RĂNG P/S SENSITIVE WHITENING 100G
# 36  9252712000295    KEM ĐÁNH RĂNG CLOSEUP KHOÁNG CHẤT & MATCHA 230G
# 37  9252712000303  KEM ĐÁNH RĂNG COLGATE MUỐI THAN HOẠT TÍNH 150G...
# 38  9252712000312        KEM ĐÁNH RĂNG COLGATE NATURAL TRÀ XANH 180G
# 41  9252712000328  KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 160G + B...
# 42  9252712000329         KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 240G
# 43  9252712000330  KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 160...
# 44  9252712000331    KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 240G
# 45  9252712000344              KEM ĐÁNH RĂNG DẠ LAN FOR FAMILY 200GR
# 49  9252712000364    KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG DÂU 80G
# 50  9252712000368     KEM ĐÁNH RĂNG CAO CẤP 2080 THAN HOẠT TÍNH 200G
# 51  9252712000372  KEM ĐÁNH RĂNG P/S BAKING SODA HƯƠNG THẢO 230G ...
# 52  9252712000374        KEM ĐÁNH RĂNG P/S SENSITIVE PRO-ACTION 105G
# 53  9252712000413  KEM ĐÁNH RĂNG COLGATE MAXFRESH TINH CHẤT THAN ...
# 54  9252712000432             BỘ 2 KEM ĐÁNH RĂNG P/S BẢO VỆ 123 180G
# 55  9252712000438  BỘ KEM ĐÁNH RĂNG CLOSEUP MUỐI BIỂN VÀ CHANH 23...
# 56  9252836000012  KDR COLGATE NGUA SAU RANG TOI DA 250G/225G + B...
# 57  9252836000039           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 240G/230G
# 58  9252836000043         KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 100G/60 ỐNG
# 59  9252836000044  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 60  9252836000183          KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
#
#     TT theo số lượng
# 0           1.720914
# 1           3.288018
# 2           3.804348
# 3           1.413121
# 4           1.572488
# 5           1.638535
# 6           3.386926
# 7           1.639712
# 8           1.336434
# 9           1.987040
# 10          1.258828
# 11          4.347785
# 12          4.018220
# 15          1.775570
# 16          2.020682
# 17          4.244160
# 18          3.667755
# 19          1.569041
# 20          1.859038
# 24          1.948364
# 25          1.629647
# 26          1.828464
# 29          1.594344
# 30          5.085396
# 31          1.672338
# 32          1.928305
# 33          1.179460
# 34          1.641118
# 35          1.723729
# 36          1.656854
# 37          5.681268
# 38          1.481911
# 41          7.326757
# 42          5.859740
# 43          7.689196
# 44          8.699182
# 45          1.096374
# 49          1.170570
# 50          1.057617
# 51          6.859639
# 52          1.239111
# 53          1.973416
# 54          2.393505
# 55          5.007602
# 56          7.314093
# 57          4.007505
# 58          1.463675
# 59          2.317388
# 60          1.454147

# %%
df_sku_2022_hq = df_sku_2022_hq.rename(columns={'TT theo số lượng': 'TT 2022'})

# %% [markdown]
# ## 2023:

# %%
df_sku_2023 = master_df1[['Mã SP chính', 'Tỷ lệ tăng trưởng']]
df_sku_2023
# Out:
#          Mã SP chính  Tỷ lệ tăng trưởng
# 0      9252712000368           1.399580
# 1      9252712000368           0.000000
# 2      9252712000368           0.000000
# 3      9252712000368           0.000000
# 4      9252712000368           0.000000
# ...              ...                ...
# 94968  9252712000084           2.422350
# 94969  9252712000084           2.691500
# 94970  9252712000084           1.346221
# 94971  9252712000084           1.938423
# 94972  9252712000084           0.000000
#
# [94973 rows x 2 columns]

# %%
df_sku_2023 = df_sku_2023.groupby('Mã SP chính')['Tỷ lệ tăng trưởng'].mean().reset_index()
df_sku_2023
# Out:
#       Mã SP chính  Tỷ lệ tăng trưởng
# 0   8934839103903           0.036761
# 1   8934839121686           6.934159
# 2   8934839121723           5.142358
# 3   8935102105754           0.543478
# 4   8935102105860           0.009149
# 5   8935102105891           0.007161
# 6   9252712000007           0.104344
# 7   9252712000018           0.091747
# 8   9252712000019           0.071288
# 9   9252712000029           0.090269
# 10  9252712000040           0.008569
# 11  9252712000043           1.517442
# 12  9252712000044           0.987837
# 13  9252712000045           0.000000
# 14  9252712000062           0.024097
# 15  9252712000066           1.153596
# 16  9252712000069           0.008018
# 17  9252712000077           0.885682
# 18  9252712000084           3.373560
# 19  9252712000112           0.000000
# 20  9252712000169           0.715958
# 21  9252712000172           0.012275
# 22  9252712000174           0.003395
# 23  9252712000201           0.007934
# 24  9252712000202           0.005768
# 25  9252712000203           0.891673
# 26  9252712000214           1.039102
# 27  9252712000215           0.006593
# 28  9252712000218           0.138030
# 29  9252712000219           0.114436
# 30  9252712000260           1.143431
# 31  9252712000261           1.222489
# 32  9252712000303           0.580518
# 33  9252712000312           0.006022
# 34  9252712000363           0.184236
# 35  9252712000368           0.171392
# 36  9252712000372           1.297182
# 37  9252712000374           1.044088
# 38  9252712000413           0.001531
# 39  9252712000432           1.191123
# 40  9252712000438           1.641515
# 41  9252836000012           1.224909
# 42  9252836000039           1.204986
# 43  9252836000043           0.042484
# 44  9252836000044           1.451370
# 45  9252836000183           0.042263

# %%
df_sku_2023_hq = df_sku_2023[df_sku_2023['Tỷ lệ tăng trưởng'] >= 1.0]
df_sku_2023_hq
# Out:
#       Mã SP chính  Tỷ lệ tăng trưởng
# 1   8934839121686           6.934159
# 2   8934839121723           5.142358
# 11  9252712000043           1.517442
# 15  9252712000066           1.153596
# 18  9252712000084           3.373560
# 26  9252712000214           1.039102
# 30  9252712000260           1.143431
# 31  9252712000261           1.222489
# 36  9252712000372           1.297182
# 37  9252712000374           1.044088
# 39  9252712000432           1.191123
# 40  9252712000438           1.641515
# 41  9252836000012           1.224909
# 42  9252836000039           1.204986
# 44  9252836000044           1.451370

# %%
df_sku_2023_hq = df_sku_2023_hq.rename(columns={'Tỷ lệ tăng trưởng': 'TT 2023'})

# %%
df_hq = df_sku_2022_hq.merge(df_sku_2023_hq, how = 'left', on = 'Mã SP chính')
df_hq
# Out:
#       Mã SP chính                                       Tên sản phẩm  \
# 0   8934839103903      KEM ĐÁNH RĂNG P/S BÉ NGOAN 35G (TRẺ EM H.DÂU)
# 1   8934839121686            KEM ĐÁNH RĂNG CLOSEUP HƯƠNG BẠC HÀ 230G
# 2   8934839121723     KEM ĐÁNH RĂNG CLOSEUP TINH THỂ BĂNG TUYẾT 230G
# 3   8935102105754                       KDR COLGATE OPTIC WHITE 100G
# 4   8935102105860              KDR COLGATE MAXFRESH BẠC HÀ 200G/180G
# 5   8935102105891  KEM ĐÁNH RĂNG COLGATE MAXFRESH TRÀ XANH 200G/180G
# 6   9252712000007  KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG VƯỢT TRỘI 240G...
# 7   9252712000018           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 190G/180G
# 8   9252712000019  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 9   9252712000029  KEM ĐÁNH RĂNG BẢO VỆ 1 2 3/ TRẮNG RĂNG THAN HO...
# 10  9252712000040                   KĐR Colgate Natural Seaweed 180g
# 11  9252712000043            KDR COLGATE MAXFRESH BẠC HÀ 230G + BCDR
# 12  9252712000044  KDR COLGATE MAXFRESH THỔI BÙNG SẢNG KHOÁI 230G...
# 13  9252712000066                KDR CLOSEUP DỪA THAN HOẠT TÍNH 180G
# 14  9252712000069         Kem Đánh Răng Col Muối Thảo Dược 250G/225G
# 15  9252712000077          KDR COLGATE MAXFRESH TRÀ XANH 230G + BCDR
# 16  9252712000084   KEM ĐÁNH RĂNG P/S TRẮNG RĂNG THAN HOẠT TÍNH 230G
# 17  9252712000094    KĐR CLOSE UP THƠM MÁT DÂU QUẤT & THẢO DƯỢC 180G
# 18  9252712000111   KDR COLGATE TOTAL CHARCOAL DEEP CLEAN 190g/ 170g
# 19  9252712000169                KĐR COLGATE THAN TRE VÀ BẠC HÀ 180G
# 20  9252712000172  KEM ĐÁNH RĂNG TRẺ EM COLGATE MINION 80G/MILD M...
# 21  9252712000174                       KĐR TRẺ EM COLGATE TIGER 40G
# 22  9252712000203  BỘ 2 KEM ĐÁNH RĂNG COLGATE MAXFRESH HƯƠNG BẠC ...
# 23  9252712000214  KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 225G +...
# 24  9252712000215       KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 200G
# 25  9252712000218    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 180G
# 26  9252712000219    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 230G
# 27  9252712000260        KEM ĐÁNH RĂNG P/S SENSITIVE FRESH MINT 100G
# 28  9252712000261         KEM ĐÁNH RĂNG P/S SENSITIVE WHITENING 100G
# 29  9252712000295    KEM ĐÁNH RĂNG CLOSEUP KHOÁNG CHẤT & MATCHA 230G
# 30  9252712000303  KEM ĐÁNH RĂNG COLGATE MUỐI THAN HOẠT TÍNH 150G...
# 31  9252712000312        KEM ĐÁNH RĂNG COLGATE NATURAL TRÀ XANH 180G
# 32  9252712000328  KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 160G + B...
# 33  9252712000329         KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 240G
# 34  9252712000330  KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 160...
# 35  9252712000331    KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 240G
# 36  9252712000344              KEM ĐÁNH RĂNG DẠ LAN FOR FAMILY 200GR
# 37  9252712000364    KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG DÂU 80G
# 38  9252712000368     KEM ĐÁNH RĂNG CAO CẤP 2080 THAN HOẠT TÍNH 200G
# 39  9252712000372  KEM ĐÁNH RĂNG P/S BAKING SODA HƯƠNG THẢO 230G ...
# 40  9252712000374        KEM ĐÁNH RĂNG P/S SENSITIVE PRO-ACTION 105G
# 41  9252712000413  KEM ĐÁNH RĂNG COLGATE MAXFRESH TINH CHẤT THAN ...
# 42  9252712000432             BỘ 2 KEM ĐÁNH RĂNG P/S BẢO VỆ 123 180G
# 43  9252712000438  BỘ KEM ĐÁNH RĂNG CLOSEUP MUỐI BIỂN VÀ CHANH 23...
# 44  9252836000012  KDR COLGATE NGUA SAU RANG TOI DA 250G/225G + B...
# 45  9252836000039           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 240G/230G
# 46  9252836000043         KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 100G/60 ỐNG
# 47  9252836000044  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 48  9252836000183          KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
#
#      TT 2022   TT 2023
# 0   1.720914       NaN
# 1   3.288018  6.934159
# 2   3.804348  5.142358
# 3   1.413121       NaN
# 4   1.572488       NaN
# 5   1.638535       NaN
# 6   3.386926       NaN
# 7   1.639712       NaN
# 8   1.336434       NaN
# 9   1.987040       NaN
# 10  1.258828       NaN
# 11  4.347785  1.517442
# 12  4.018220       NaN
# 13  1.775570  1.153596
# 14  2.020682       NaN
# 15  4.244160       NaN
# 16  3.667755  3.373560
# 17  1.569041       NaN
# 18  1.859038       NaN
# 19  1.948364       NaN
# 20  1.629647       NaN
# 21  1.828464       NaN
# 22  1.594344       NaN
# 23  5.085396  1.039102
# 24  1.672338       NaN
# 25  1.928305       NaN
# 26  1.179460       NaN
# 27  1.641118  1.143431
# 28  1.723729  1.222489
# 29  1.656854       NaN
# 30  5.681268       NaN
# 31  1.481911       NaN
# 32  7.326757       NaN
# 33  5.859740       NaN
# 34  7.689196       NaN
# 35  8.699182       NaN
# 36  1.096374       NaN
# 37  1.170570       NaN
# 38  1.057617       NaN
# 39  6.859639  1.297182
# 40  1.239111  1.044088
# 41  1.973416       NaN
# 42  2.393505  1.191123
# 43  5.007602  1.641515
# 44  7.314093  1.224909
# 45  4.007505  1.204986
# 46  1.463675       NaN
# 47  2.317388  1.451370
# 48  1.454147       NaN

# %%
df_hq = df_hq.fillna('Not Available')
df_hq
# Out:
#       Mã SP chính                                       Tên sản phẩm  \
# 0   8934839103903      KEM ĐÁNH RĂNG P/S BÉ NGOAN 35G (TRẺ EM H.DÂU)
# 1   8934839121686            KEM ĐÁNH RĂNG CLOSEUP HƯƠNG BẠC HÀ 230G
# 2   8934839121723     KEM ĐÁNH RĂNG CLOSEUP TINH THỂ BĂNG TUYẾT 230G
# 3   8935102105754                       KDR COLGATE OPTIC WHITE 100G
# 4   8935102105860              KDR COLGATE MAXFRESH BẠC HÀ 200G/180G
# 5   8935102105891  KEM ĐÁNH RĂNG COLGATE MAXFRESH TRÀ XANH 200G/180G
# 6   9252712000007  KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG VƯỢT TRỘI 240G...
# 7   9252712000018           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 190G/180G
# 8   9252712000019  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 9   9252712000029  KEM ĐÁNH RĂNG BẢO VỆ 1 2 3/ TRẮNG RĂNG THAN HO...
# 10  9252712000040                   KĐR Colgate Natural Seaweed 180g
# 11  9252712000043            KDR COLGATE MAXFRESH BẠC HÀ 230G + BCDR
# 12  9252712000044  KDR COLGATE MAXFRESH THỔI BÙNG SẢNG KHOÁI 230G...
# 13  9252712000066                KDR CLOSEUP DỪA THAN HOẠT TÍNH 180G
# 14  9252712000069         Kem Đánh Răng Col Muối Thảo Dược 250G/225G
# 15  9252712000077          KDR COLGATE MAXFRESH TRÀ XANH 230G + BCDR
# 16  9252712000084   KEM ĐÁNH RĂNG P/S TRẮNG RĂNG THAN HOẠT TÍNH 230G
# 17  9252712000094    KĐR CLOSE UP THƠM MÁT DÂU QUẤT & THẢO DƯỢC 180G
# 18  9252712000111   KDR COLGATE TOTAL CHARCOAL DEEP CLEAN 190g/ 170g
# 19  9252712000169                KĐR COLGATE THAN TRE VÀ BẠC HÀ 180G
# 20  9252712000172  KEM ĐÁNH RĂNG TRẺ EM COLGATE MINION 80G/MILD M...
# 21  9252712000174                       KĐR TRẺ EM COLGATE TIGER 40G
# 22  9252712000203  BỘ 2 KEM ĐÁNH RĂNG COLGATE MAXFRESH HƯƠNG BẠC ...
# 23  9252712000214  KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 225G +...
# 24  9252712000215       KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 200G
# 25  9252712000218    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 180G
# 26  9252712000219    KEM ĐÁNH RĂNG P/S BAKING SODA & HƯƠNG THẢO 230G
# 27  9252712000260        KEM ĐÁNH RĂNG P/S SENSITIVE FRESH MINT 100G
# 28  9252712000261         KEM ĐÁNH RĂNG P/S SENSITIVE WHITENING 100G
# 29  9252712000295    KEM ĐÁNH RĂNG CLOSEUP KHOÁNG CHẤT & MATCHA 230G
# 30  9252712000303  KEM ĐÁNH RĂNG COLGATE MUỐI THAN HOẠT TÍNH 150G...
# 31  9252712000312        KEM ĐÁNH RĂNG COLGATE NATURAL TRÀ XANH 180G
# 32  9252712000328  KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 160G + B...
# 33  9252712000329         KEM ĐÁNH RĂNG PURI THẢO DƯỢC TRÀ XANH 240G
# 34  9252712000330  KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 160...
# 35  9252712000331    KEM ĐÁNH RĂNG PURI NGỪA SÂU RĂNG TOÀN DIỆN 240G
# 36  9252712000344              KEM ĐÁNH RĂNG DẠ LAN FOR FAMILY 200GR
# 37  9252712000364    KEM ĐÁNH RĂNG TRẺ EM CAO CẤP 2080 HƯƠNG DÂU 80G
# 38  9252712000368     KEM ĐÁNH RĂNG CAO CẤP 2080 THAN HOẠT TÍNH 200G
# 39  9252712000372  KEM ĐÁNH RĂNG P/S BAKING SODA HƯƠNG THẢO 230G ...
# 40  9252712000374        KEM ĐÁNH RĂNG P/S SENSITIVE PRO-ACTION 105G
# 41  9252712000413  KEM ĐÁNH RĂNG COLGATE MAXFRESH TINH CHẤT THAN ...
# 42  9252712000432             BỘ 2 KEM ĐÁNH RĂNG P/S BẢO VỆ 123 180G
# 43  9252712000438  BỘ KEM ĐÁNH RĂNG CLOSEUP MUỐI BIỂN VÀ CHANH 23...
# 44  9252836000012  KDR COLGATE NGUA SAU RANG TOI DA 250G/225G + B...
# 45  9252836000039           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 240G/230G
# 46  9252836000043         KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 100G/60 ỐNG
# 47  9252836000044  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
# 48  9252836000183          KEM ĐÁNH RĂNG P/S NGỪA SÂU RĂNG 110G/100G
#
#      TT 2022        TT 2023
# 0   1.720914  Not Available
# 1   3.288018       6.934159
# 2   3.804348       5.142358
# 3   1.413121  Not Available
# 4   1.572488  Not Available
# 5   1.638535  Not Available
# 6   3.386926  Not Available
# 7   1.639712  Not Available
# 8   1.336434  Not Available
# 9   1.987040  Not Available
# 10  1.258828  Not Available
# 11  4.347785       1.517442
# 12  4.018220  Not Available
# 13  1.775570       1.153596
# 14  2.020682  Not Available
# 15  4.244160  Not Available
# 16  3.667755        3.37356
# 17  1.569041  Not Available
# 18  1.859038  Not Available
# 19  1.948364  Not Available
# 20  1.629647  Not Available
# 21  1.828464  Not Available
# 22  1.594344  Not Available
# 23  5.085396       1.039102
# 24  1.672338  Not Available
# 25  1.928305  Not Available
# 26  1.179460  Not Available
# 27  1.641118       1.143431
# 28  1.723729       1.222489
# 29  1.656854  Not Available
# 30  5.681268  Not Available
# 31  1.481911  Not Available
# 32  7.326757  Not Available
# 33  5.859740  Not Available
# 34  7.689196  Not Available
# 35  8.699182  Not Available
# 36  1.096374  Not Available
# 37  1.170570  Not Available
# 38  1.057617  Not Available
# 39  6.859639       1.297182
# 40  1.239111       1.044088
# 41  1.973416  Not Available
# 42  2.393505       1.191123
# 43  5.007602       1.641515
# 44  7.314093       1.224909
# 45  4.007505       1.204986
# 46  1.463675  Not Available
# 47  2.317388        1.45137
# 48  1.454147  Not Available

# %%
df_kq = df_hq[df_hq['TT 2023'] != 'Not Available']
df_kq
# Out:
#       Mã SP chính                                       Tên sản phẩm  \
# 1   8934839121686            KEM ĐÁNH RĂNG CLOSEUP HƯƠNG BẠC HÀ 230G
# 2   8934839121723     KEM ĐÁNH RĂNG CLOSEUP TINH THỂ BĂNG TUYẾT 230G
# 11  9252712000043            KDR COLGATE MAXFRESH BẠC HÀ 230G + BCDR
# 13  9252712000066                KDR CLOSEUP DỪA THAN HOẠT TÍNH 180G
# 16  9252712000084   KEM ĐÁNH RĂNG P/S TRẮNG RĂNG THAN HOẠT TÍNH 230G
# 23  9252712000214  KĐR COLGATE MAXFRESH TINH CHẤT THAN TRE 225G +...
# 27  9252712000260        KEM ĐÁNH RĂNG P/S SENSITIVE FRESH MINT 100G
# 28  9252712000261         KEM ĐÁNH RĂNG P/S SENSITIVE WHITENING 100G
# 39  9252712000372  KEM ĐÁNH RĂNG P/S BAKING SODA HƯƠNG THẢO 230G ...
# 40  9252712000374        KEM ĐÁNH RĂNG P/S SENSITIVE PRO-ACTION 105G
# 42  9252712000432             BỘ 2 KEM ĐÁNH RĂNG P/S BẢO VỆ 123 180G
# 43  9252712000438  BỘ KEM ĐÁNH RĂNG CLOSEUP MUỐI BIỂN VÀ CHANH 23...
# 44  9252836000012  KDR COLGATE NGUA SAU RANG TOI DA 250G/225G + B...
# 45  9252836000039           KEM ĐÁNH RĂNG P/S 123 TRÀ XANH 240G/230G
# 47  9252836000044  KEM ĐÁNH RĂNG P/S BẢO VỆ 123 CHĂM SÓC TOÀN DIỆ...
#
#      TT 2022   TT 2023
# 1   3.288018  6.934159
# 2   3.804348  5.142358
# 11  4.347785  1.517442
# 13  1.775570  1.153596
# 16  3.667755   3.37356
# 23  5.085396  1.039102
# 27  1.641118  1.143431
# 28  1.723729  1.222489
# 39  6.859639  1.297182
# 40  1.239111  1.044088
# 42  2.393505  1.191123
# 43  5.007602  1.641515
# 44  7.314093  1.224909
# 45  4.007505  1.204986
# 47  2.317388   1.45137

# %%
df_kq.to_excel('task3kdr.xlsx')
